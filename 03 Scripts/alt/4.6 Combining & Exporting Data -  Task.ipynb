# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
path = r'C:\Users\s.wienecke\Documents\Fortbildung\Instacart Basket Analysis'

# %%
# orders_products_combined stands for orders_products_combined.pkl
df_orders_products_combined = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
# df_products stands for products.csv 
df_products = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_clean.csv'), index_col = False)

# %% [markdown]
# # Shape of imported data

# %%
df_orders_products_combined.shape
# Out:
# (32640698, 12)

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0         1.0           1.0   2398795      1.0    prior           2.0
# 1         1.0           1.0   2398795      1.0    prior           2.0
# 2         1.0           1.0   2398795      1.0    prior           2.0
# 3         1.0           1.0   2398795      1.0    prior           2.0
# 4         1.0           1.0   2398795      1.0    prior           2.0
#
#    orders_day_of_week  order_time  days_since_prior_order  product_id  \
# 0                 3.0         7.0                    15.0       196.0
# 1                 3.0         7.0                    15.0     10258.0
# 2                 3.0         7.0                    15.0     12427.0
# 3                 3.0         7.0                    15.0     13176.0
# 4                 3.0         7.0                    15.0     26088.0
#
#    add_to_cart_order  reordered
# 0                1.0        1.0
# 1                2.0        0.0
# ...

# %%
# remove unnecessary column
df_orders_products_combined_1 = df_orders_products_combined.drop(columns = ['Unnamed: 0.1','Unnamed: 0'])

# %%
df_orders_products_combined_1.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_time  \
# 0   2398795      1.0    prior           2.0                 3.0         7.0
# 1   2398795      1.0    prior           2.0                 3.0         7.0
# 2   2398795      1.0    prior           2.0                 3.0         7.0
# 3   2398795      1.0    prior           2.0                 3.0         7.0
# 4   2398795      1.0    prior           2.0                 3.0         7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0

# %%
df_products.shape
# Out:
# (49672, 6)

# %%
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# remove unnecessary column
df_products = df_products.drop(columns = ['Unnamed: 0',])

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# # Merge orders_products_combined with products data set

# %%
# Merging orders_products_combined with products data set
orders_products_merged = df_orders_products_combined_1.merge(df_products, on = ['product_id'], how = 'left',indicator = True)

# %%
orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_time  \
# 0   2398795      1.0    prior           2.0                 3.0         7.0
# 1   2398795      1.0    prior           2.0                 3.0         7.0
# 2   2398795      1.0    prior           2.0                 3.0         7.0
# 3   2398795      1.0    prior           2.0                 3.0         7.0
# 4   2398795      1.0    prior           2.0                 3.0         7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0       196.0                1.0        1.0
# 1                    15.0     10258.0                2.0        0.0
# 2                    15.0     12427.0                3.0        1.0
# 3                    15.0     13176.0                4.0        0.0
# 4                    15.0     26088.0                5.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# # Confirm using the merge flag

# %%
orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only       236409
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # Export

# %%
orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
